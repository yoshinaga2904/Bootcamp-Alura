# %% [markdown]
# <a href="https://colab.research.google.com/github/yoshinaga2904/Bootcamp-Alura/blob/main/Series_temporais_Tuberculose.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-cursos/serie_temporal_bootcamp/main/tuberculose_ano_mes_diagnostico.csv"

dados = pd.read_csv(url, encoding = "ISO-8859-1", sep = ";", skiprows=3, skipfooter=16, engine="python")
dados.head()
# Out:
#   Ano Diagnóstico   Jan   Fev   Mar   Abr  ...   Set   Out   Nov   Dez  Total
# 0            2001  8088  6542  8095  7305  ...  6697  7524  6874  6627  87265
# 1            2002  8013  7346  7961  8771  ...  7654  8200  7532  6809  92859
# 2            2003  8115  7985  7474  7975  ...  8136  8521  7624  7303  93773
# 3            2004  7574  6743  8574  8089  ...  7901  8016  7753  7196  92980
# 4            2005  7432  6748  8441  7958  ...  7690  7186  7587  7541  92056
#
# [5 rows x 14 columns]

# %%
dados.tail()
# Out:
#    Ano Diagnóstico     Jan     Fev     Mar  ...     Out     Nov     Dez    Total
# 15            2016    7116    6800    8067  ...    6588    7039    6672    86207
# 16            2017    7481    6803    8680  ...    7809    7451    7020    90291
# 17            2018    7881    6821    7901  ...    8701    7711    6900    94354
# 18            2019    8392    7754    7648  ...    8592    7615    7220    96005
# 19           Total  142969  129386  149875  ...  144870  136864  128893  1684757
#
# [5 rows x 14 columns]

# %%
dados
# Out:
#    Ano Diagnóstico     Jan     Fev     Mar  ...     Out     Nov     Dez    Total
# 0             2001    8088    6542    8095  ...    7524    6874    6627    87265
# 1             2002    8013    7346    7961  ...    8200    7532    6809    92859
# 2             2003    8115    7985    7474  ...    8521    7624    7303    93773
# 3             2004    7574    6743    8574  ...    8016    7753    7196    92980
# 4             2005    7432    6748    8441  ...    7186    7587    7541    92056
# 5             2006    7385    6687    8132  ...    7005    6674    6151    85031
# 6             2007    7342    6204    8115  ...    7465    6695    6094    84600
# 7             2008    7355    6646    7278  ...    7564    6799    6574    86768
# 8             2009    7113    6452    8146  ...    7285    7016    6723    86318
# 9             2010    6912    6403    8308  ...    7210    7047    7176    85381
# 10            2011    7112    7269    7484  ...    6994    7375    6936    87813
# 11            2012    7375    6774    7882  ...    7606    6941    6302    86183
# 12            2013    7502    6209    7102  ...    7789    6939    6335    86208
# 13            2014    7670    7040    6754  ...    7470    6905    6470    85213
# 14            2015    7111    6160    7833  ...    7345    7287    6844    85452
# 15            2016    7116    6800    8067  ...    6588    7039    6672    86207
# 16            2017    7481    6803    8680  ...    7809    7451    7020    90291
# 17            2018    7881    6821    7901  ...    8701    7711    6900    94354
# 18            2019    8392    7754    7648  ...    8592    7615    7220    96005
# 19           Total  142969  129386  149875  ...  144870  136864  128893  1684757
#
# [20 rows x 14 columns]

# %%
dados.drop("Total",axis=1,inplace=True)
dados.drop(19,inplace=True)

# %%
dados
# Out:
#    Ano Diagnóstico   Jan   Fev   Mar   Abr  ...   Ago   Set   Out   Nov   Dez
# 0             2001  8088  6542  8095  7305  ...  8065  6697  7524  6874  6627
# 1             2002  8013  7346  7961  8771  ...  8330  7654  8200  7532  6809
# 2             2003  8115  7985  7474  7975  ...  7585  8136  8521  7624  7303
# 3             2004  7574  6743  8574  8089  ...  8232  7901  8016  7753  7196
# 4             2005  7432  6748  8441  7958  ...  8391  7690  7186  7587  7541
# 5             2006  7385  6687  8132  6804  ...  7722  6793  7005  6674  6151
# 6             2007  7342  6204  8115  7266  ...  7564  6712  7465  6695  6094
# 7             2008  7355  6646  7278  7612  ...  7797  7631  7564  6799  6574
# 8             2009  7113  6452  8146  7514  ...  7368  7388  7285  7016  6723
# 9             2010  6912  6403  8308  7049  ...  7389  7165  7210  7047  7176
# 10            2011  7112  7269  7484  7558  ...  7992  7386  6994  7375  6936
# 11            2012  7375  6774  7882  6927  ...  8014  6734  7606  6941  6302
# 12            2013  7502  6209  7102  7696  ...  7931  7377  7789  6939  6335
# 13            2014  7670  7040  6754  7260  ...  7124  7505  7470  6905  6470
# 14            2015  7111  6160  7833  6880  ...  7463  7189  7345  7287  6844
# 15            2016  7116  6800  8067  7360  ...  7702  7030  6588  7039  6672
# 16            2017  7481  6803  8680  6780  ...  8110  7447  7809  7451  7020
# 17            2018  7881  6821  7901  8121  ...  8934  7663  8701  7711  6900
# 18            2019  8392  7754  7648  8274  ...  8239  8143  8592  7615  7220
#
# [19 rows x 13 columns]

# %% [markdown]
# # Desafio 01: transformar os dados em uma série temporal Ano-Mês

# %%
dados_serie_temporal = dados.melt(id_vars="Ano Diagnóstico",var_name="Mês", value_name="Casos")
dados_serie_temporal["data"] = dados_serie_temporal["Ano Diagnóstico"]+"-"+dados_serie_temporal["Mês"]
dados_serie_temporal
# Out:
#     Ano Diagnóstico  Mês  Casos      data
# 0              2001  Jan   8088  2001-Jan
# 1              2002  Jan   8013  2002-Jan
# 2              2003  Jan   8115  2003-Jan
# 3              2004  Jan   7574  2004-Jan
# 4              2005  Jan   7432  2005-Jan
# ..              ...  ...    ...       ...
# 223            2015  Dez   6844  2015-Dez
# 224            2016  Dez   6672  2016-Dez
# 225            2017  Dez   7020  2017-Dez
# 226            2018  Dez   6900  2018-Dez
# 227            2019  Dez   7220  2019-Dez
#
# [228 rows x 4 columns]

# %% [markdown]
# # Desafio 02: Converter a data (String) em Datatime

# %%
dados_serie_temporal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228 entries, 0 to 227
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ano Diagnóstico  228 non-null    object
#  1   Mês              228 non-null    object
#  2   Casos            228 non-null    int64
#  3   data             228 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 7.2+ KB

# %%
# Para utilizar a transformação do datetime, precisamos converter do portugues
#para o ingles, os meses.
meses_portugues_ingles = {
    "Jan": "Jan",
    "Fev": "Feb",
    "Mar": "Mar",
    "Abr": "Apr",
    "Mai": "May",
    "Jun": "Jun",
    "Jul": "Jul",
    "Ago": "Aug",
    "Set": "Sep",
    "Out": "Oct",
    "Nov": "Nov",
    "Dez": "Dec"
}

dados_serie_temporal["Mês"] = dados_serie_temporal["Mês"].map(meses_portugues_ingles)
dados_serie_temporal.sample(5)
# Out:
#     Ano Diagnóstico  Mês  Casos      data
# 101            2007  Jun   6591  2007-Jun
# 16             2017  Jan   7481  2017-Jan
# 79             2004  May   7763  2004-Mai
# 104            2010  Jun   6621  2010-Jun
# 194            2005  Nov   7587  2005-Nov

# %%
dados_serie_temporal["data"] = dados_serie_temporal["Ano Diagnóstico"]+"-"+dados_serie_temporal["Mês"]
dados_serie_temporal
# Out:
#     Ano Diagnóstico  Mês  Casos      data
# 0              2001  Jan   8088  2001-Jan
# 1              2002  Jan   8013  2002-Jan
# 2              2003  Jan   8115  2003-Jan
# 3              2004  Jan   7574  2004-Jan
# 4              2005  Jan   7432  2005-Jan
# ..              ...  ...    ...       ...
# 223            2015  Dec   6844  2015-Dec
# 224            2016  Dec   6672  2016-Dec
# 225            2017  Dec   7020  2017-Dec
# 226            2018  Dec   6900  2018-Dec
# 227            2019  Dec   7220  2019-Dec
#
# [228 rows x 4 columns]

# %%
dados_serie_temporal["Data"] = pd.to_datetime(dados_serie_temporal["data"])
dados_serie_temporal
# Out:
#     Ano Diagnóstico  Mês  Casos      data       Data
# 0              2001  Jan   8088  2001-Jan 2001-01-01
# 1              2002  Jan   8013  2002-Jan 2002-01-01
# 2              2003  Jan   8115  2003-Jan 2003-01-01
# 3              2004  Jan   7574  2004-Jan 2004-01-01
# 4              2005  Jan   7432  2005-Jan 2005-01-01
# ..              ...  ...    ...       ...        ...
# 223            2015  Dec   6844  2015-Dec 2015-12-01
# 224            2016  Dec   6672  2016-Dec 2016-12-01
# 225            2017  Dec   7020  2017-Dec 2017-12-01
# 226            2018  Dec   6900  2018-Dec 2018-12-01
# 227            2019  Dec   7220  2019-Dec 2019-12-01
#
# [228 rows x 5 columns]

# %%
dados_serie_temporal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228 entries, 0 to 227
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ano Diagnóstico  228 non-null    object
#  1   Mês              228 non-null    object
#  2   Casos            228 non-null    int64
#  3   data             228 non-null    object
#  4   Data             228 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 9.0+ KB

# %%
dados_serie_temporal = dados_serie_temporal[["Data", "Casos"]]
dados_serie_temporal
# Out:
#           Data  Casos
# 0   2001-01-01   8088
# 1   2002-01-01   8013
# 2   2003-01-01   8115
# 3   2004-01-01   7574
# 4   2005-01-01   7432
# ..         ...    ...
# 223 2015-12-01   6844
# 224 2016-12-01   6672
# 225 2017-12-01   7020
# 226 2018-12-01   6900
# 227 2019-12-01   7220
#
# [228 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15,5))
sns.lineplot(x="Data", y="Casos", data=dados_serie_temporal)
plt.title("Série Temporal Casos de Tuberculose")
plt.xticks(rotation = 90)
plt.show()

# %%
dados_serie_temporal.sort_values(by=["Data"], inplace=True)
dados_serie_temporal.reset_index(drop=True, inplace=True)
dados_serie_temporal
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#           Data  Casos
# 0   2001-01-01   8088
# 1   2001-02-01   6542
# 2   2001-03-01   8095
# 3   2001-04-01   7305
# 4   2001-05-01   7656
# ..         ...    ...
# 223 2019-08-01   8239
# 224 2019-09-01   8143
# 225 2019-10-01   8592
# 226 2019-11-01   7615
# 227 2019-12-01   7220
#
# [228 rows x 2 columns]

# %%
dados_serie_temporal["Media_Movel_3"] = dados_serie_temporal["Casos"].rolling(3).mean()
plt.figure(figsize=(15,5))
sns.lineplot(x="Data", y="Casos", data=dados_serie_temporal)
sns.lineplot(x="Data", y="Media_Movel_3", data=dados_serie_temporal)
plt.title("Série Temporal Casos de Tuberculose")
plt.xticks(rotation = 90)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dados_serie_temporal["Media_Movel_3_center"] = dados_serie_temporal["Casos"].rolling(3, center=True).mean()
plt.figure(figsize=(15,5))
sns.lineplot(x="Data", y="Casos", data=dados_serie_temporal)
sns.lineplot(x="Data", y="Media_Movel_3_center", data=dados_serie_temporal)
plt.title("Série Temporal Casos de Tuberculose")
plt.xticks(rotation = 90)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dados_serie_temporal["Media_Movel_3_center"] = dados_serie_temporal["Casos"].rolling(3, center=True).mean()
plt.figure(figsize=(15,5))
sns.lineplot(x="Data", y="Casos", data=dados_serie_temporal[:50])
sns.lineplot(x="Data", y="Media_Movel_3", data=dados_serie_temporal[:50])
sns.lineplot(x="Data", y="Media_Movel_3_center", data=dados_serie_temporal[:50])
plt.title("Série Temporal Casos de Tuberculose")
plt.xticks(rotation = 90)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dados_serie_temporal["Media_Movel_6_center"] = dados_serie_temporal["Casos"].rolling(6, center=True).mean()
plt.figure(figsize=(15,5))
sns.lineplot(x="Data", y="Casos", data=dados_serie_temporal)
sns.lineplot(x="Data", y="Media_Movel_6_center", data=dados_serie_temporal)
plt.title("Série Temporal Casos de Tuberculose")
plt.xticks(rotation = 90)
plt.show()

# %%
dados_serie_temporal["Media_Movel_12_center"] = dados_serie_temporal["Casos"].rolling(12, center=True).mean()
plt.figure(figsize=(15,5))
sns.lineplot(x="Data", y="Casos", data=dados_serie_temporal)
sns.lineplot(x="Data", y="Media_Movel_12_center", data=dados_serie_temporal)
plt.title("Série Temporal Casos de Tuberculose")
plt.xticks(rotation = 90)
plt.show()

# %%
dados_serie_temporal.iloc[-3:]
# Out:
#           Data  Casos  ...  Media_Movel_6_center  Media_Movel_12_center
# 225 2019-10-01   8592  ...           8031.833333                    NaN
# 226 2019-11-01   7615  ...                   NaN                    NaN
# 227 2019-12-01   7220  ...                   NaN                    NaN
#
# [3 rows x 6 columns]

# %%
mes_previsto_3_ultimos_meses = dados_serie_temporal[["Data", "Casos"]]
mes_previsto_3_ultimos_meses["Data"] = pd.to_datetime(mes_previsto_3_ultimos_meses["Data"])
mes_previsto_3_ultimos_meses
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           Data  Casos
# 0   2001-01-01   8088
# 1   2001-02-01   6542
# 2   2001-03-01   8095
# 3   2001-04-01   7305
# 4   2001-05-01   7656
# ..         ...    ...
# 223 2019-08-01   8239
# 224 2019-09-01   8143
# 225 2019-10-01   8592
# 226 2019-11-01   7615
# 227 2019-12-01   7220
#
# [228 rows x 2 columns]

# %%
media_3_ultimos_meses = mes_previsto_3_ultimos_meses.iloc[-3:]["Casos"].mean()
media_3_ultimos_meses
# Out:
# 7809.0

# %%
mes_previsto_3_ultimos_meses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228 entries, 0 to 227
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Data    228 non-null    datetime64[ns]
#  1   Casos   228 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 3.7 KB

# %%
mes_previsto_3_ultimos_meses = mes_previsto_3_ultimos_meses.append({"Data":"2020-01-01",	"Casos":media_3_ultimos_meses}, ignore_index=True)
mes_previsto_3_ultimos_meses
# Out:
#                     Data   Casos
# 0    2001-01-01 00:00:00  8088.0
# 1    2001-02-01 00:00:00  6542.0
# 2    2001-03-01 00:00:00  8095.0
# 3    2001-04-01 00:00:00  7305.0
# 4    2001-05-01 00:00:00  7656.0
# ..                   ...     ...
# 224  2019-09-01 00:00:00  8143.0
# 225  2019-10-01 00:00:00  8592.0
# 226  2019-11-01 00:00:00  7615.0
# 227  2019-12-01 00:00:00  7220.0
# 228           2020-01-01  7809.0
#
# [229 rows x 2 columns]

# %%
mes_previsto_3_ultimos_meses["Data"] = pd.to_datetime(mes_previsto_3_ultimos_meses["Data"])
mes_previsto_3_ultimos_meses
# Out:
#           Data   Casos
# 0   2001-01-01  8088.0
# 1   2001-02-01  6542.0
# 2   2001-03-01  8095.0
# 3   2001-04-01  7305.0
# 4   2001-05-01  7656.0
# ..         ...     ...
# 224 2019-09-01  8143.0
# 225 2019-10-01  8592.0
# 226 2019-11-01  7615.0
# 227 2019-12-01  7220.0
# 228 2020-01-01  7809.0
#
# [229 rows x 2 columns]

# %%
mes_previsto_3_ultimos_meses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Data    229 non-null    datetime64[ns]
#  1   Casos   229 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 3.7 KB

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x="Data", y="Casos", data=mes_previsto_3_ultimos_meses)
plt.title("Série Temporal Casos de Tuberculose")
plt.xticks(rotation = 90)
plt.show()

# %%
sns.lineplot(x="Data", y="Casos", data=dados_serie_temporal[:12])
sns.lineplot(x="Data", y="Casos", data=dados_serie_temporal[12:24])
sns.lineplot(x="Data", y="Casos", data=dados_serie_temporal[24:36])

# %%
dados_serie_temporal.head()
# Out:
#         Data  Casos  ...  Media_Movel_6_center  Media_Movel_12_center
# 0 2001-01-01   8088  ...                   NaN                    NaN
# 1 2001-02-01   6542  ...                   NaN                    NaN
# 2 2001-03-01   8095  ...                   NaN                    NaN
# 3 2001-04-01   7305  ...           7415.166667                    NaN
# 4 2001-05-01   7656  ...           7231.666667                    NaN
#
# [5 rows x 6 columns]

# %%
dados_serie_temporal["Ano"] = dados_serie_temporal["Data"].dt.year
dados_serie_temporal["Mês"] = dados_serie_temporal["Data"].dt.month

# %%
sns.lineplot(x="Mês", y="Casos", data=dados_serie_temporal, hue="Ano")

# %%
sns.lineplot(x="Mês", y="Casos", data=dados_serie_temporal.query("Ano in [2019, 2018, 2017]"), hue="Ano")

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decomposicao = seasonal_decompose(dados_serie_temporal[["Data", "Casos"]].set_index("Data"))
decomposicao.plot();

# %%
decomposicao = seasonal_decompose(dados_serie_temporal[["Data", "Casos"]].set_index("Data"),
                                  model="multiplicative")
decomposicao.plot();

# %%
url_passageiros = "https://raw.githubusercontent.com/alura-cursos/serie_temporal_bootcamp/main/AirPassengers.csv"
dados_passageiros = pd.read_csv(url_passageiros)

# %%
dados_passageiros
# Out:
#        Month  #Passengers
# 0    1949-01          112
# 1    1949-02          118
# 2    1949-03          132
# 3    1949-04          129
# 4    1949-05          121
# ..       ...          ...
# 139  1960-08          606
# 140  1960-09          508
# 141  1960-10          461
# 142  1960-11          390
# 143  1960-12          432
#
# [144 rows x 2 columns]

# %%
dados_passageiros["Month"] = pd.to_datetime(dados_passageiros["Month"])
dados_passageiros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        144 non-null    datetime64[ns]
#  1   #Passengers  144 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 2.4 KB

# %%
sns.lineplot(x="Month", y="#Passengers", data=dados_passageiros)

# %%
decomposicao_p = seasonal_decompose(dados_passageiros.set_index("Month"))
decomposicao_p.plot();

# %%
decomposicao_p = seasonal_decompose(dados_passageiros.set_index("Month"), model="multiplicative")
decomposicao_p.plot();

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plot_acf(dados_serie_temporal["Casos"]);

# %%
plot_pacf(dados_serie_temporal["Casos"]);

# %%
plot_acf(dados_passageiros["#Passengers"]);

# %%
plot_pacf(dados_passageiros["#Passengers"]);

# %%
dados_passageiros.rename({"Month": "Data", "#Passengers": "Passageiros"}, axis=1, inplace=True)
dados_passageiros["Mês"] = dados_passageiros["Data"].dt.month
dados_passageiros["Ano"] = dados_passageiros["Data"].dt.year
dados_passageiros
# Out:
#           Data  Passageiros  Mês   Ano
# 0   1949-01-01          112    1  1949
# 1   1949-02-01          118    2  1949
# 2   1949-03-01          132    3  1949
# 3   1949-04-01          129    4  1949
# 4   1949-05-01          121    5  1949
# ..         ...          ...  ...   ...
# 139 1960-08-01          606    8  1960
# 140 1960-09-01          508    9  1960
# 141 1960-10-01          461   10  1960
# 142 1960-11-01          390   11  1960
# 143 1960-12-01          432   12  1960
#
# [144 rows x 4 columns]

# %%
sns.lineplot(x="Mês", y="Passageiros", data=dados_passageiros, hue="Ano")

# %%
decomposicao_p.seasonal.plot();

# %%
decomposicao_p.seasonal[:12].plot();

# %%
decomposicao.seasonal[:12].plot();

# %%
from statsmodels.tsa.arima_model import ARIMA

dados_treino = dados_serie_temporal.query("Ano != 2019")
dados_teste = dados_serie_temporal.query("Ano == 2019")

modelo_arima = ARIMA(dados_treino["Casos"].values.astype("float32"), order=[12,1,2])
modelo_arima_treinado = modelo_arima.fit()
previsao = modelo_arima_treinado.forecast(12)[0]
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)

# %%
dados_teste["previsao"] = previsao
plt.figure(figsize=(10,6))
sns.lineplot(x="Data", y="Casos", data=dados_treino)
sns.lineplot(x="Data", y="Casos", data=dados_teste)
sns.lineplot(x="Data", y="previsao", data=dados_teste)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dados_treino_passageiros = dados_passageiros.query("Ano != 1960")
dados_teste_passageiros = dados_passageiros.query("Ano == 1960")

modelo_arima = ARIMA(dados_treino_passageiros["Passageiros"].values.astype("float32"), order=[2,1,2])
modelo_arima_treinado = modelo_arima.fit()
previsao = modelo_arima_treinado.forecast(12)[0]
dados_teste_passageiros["previsao"] = previsao
plt.figure(figsize=(10,6))
sns.lineplot(x="Data", y="Passageiros", data=dados_treino_passageiros)
sns.lineplot(x="Data", y="Passageiros", data=dados_teste_passageiros)
sns.lineplot(x="Data", y="previsao", data=dados_teste_passageiros)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
#!pip install pmdarima

# %%
from pmdarima.arima import auto_arima

modelo_autoarima = auto_arima(dados_treino["Casos"].values, error_action="ignore", trace=True, seasonal=True, m = 12)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=1.80 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=3462.510, Time=0.02 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=3289.199, Time=0.35 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=3249.086, Time=0.61 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=3460.524, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=3312.298, Time=0.16 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.72 sec
#  ARIMA(0,1,1)(0,0,2)[12] intercept   : AIC=3246.454, Time=1.82 sec
#  ARIMA(0,1,1)(1,0,2)[12] intercept   : AIC=inf, Time=3.62 sec
#  ARIMA(0,1,0)(0,0,2)[12] intercept   : AIC=3398.593, Time=1.10 sec
#  ARIMA(1,1,1)(0,0,2)[12] intercept   : AIC=3242.479, Time=2.22 sec
#  ARIMA(1,1,1)(0,0,1)[12] intercept   : AIC=3246.995, Time=0.85 sec
#  ARIMA(1,1,1)(1,0,2)[12] intercept   : AIC=3198.483, Time=3.52 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=1.92 sec
#  ARIMA(1,1,1)(2,0,2)[12] intercept   : AIC=inf, Time=3.12 sec
#  ARIMA(1,1,1)(2,0,1)[12] intercept   : AIC=inf, Time=2.95 sec
#  ARIMA(1,1,0)(1,0,2)[12] intercept   : AIC=inf, Time=2.77 sec
#  ARIMA(2,1,1)(1,0,2)[12] intercept   : AIC=3198.436, Time=3.55 sec
#  ARIMA(2,1,1)(0,0,2)[12] intercept   : AIC=3244.248, Time=2.96 sec
#  ARIMA(2,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=2.19 sec
#  ARIMA(2,1,1)(2,0,2)[12] intercept   : AIC=inf, Time=nan sec
#  ARIMA(2,1,1)(0,0,1)[12] intercept   : AIC=3248.365, Time=1.26 sec
#  ARIMA(2,1,1)(2,0,1)[12] intercept   : AIC=3212.707, Time=3.59 sec
#  ARIMA(2,1,0)(1,0,2)[12] intercept   : AIC=inf, Time=3.50 sec
#  ARIMA(3,1,1)(1,0,2)[12] intercept   : AIC=inf, Time=4.10 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=inf, Time=4.73 sec
#  ARIMA(1,1,2)(1,0,2)[12] intercept   : AIC=inf, Time=3.63 sec
#  ARIMA(3,1,0)(1,0,2)[12] intercept   : AIC=3205.717, Time=3.30 sec
#  ARIMA(3,1,2)(1,0,2)[12] intercept   : AIC=inf, Time=4.24 sec
#  ARIMA(2,1,1)(1,0,2)[12]             : AIC=inf, Time=3.69 sec
#
# Best model:  ARIMA(2,1,1)(1,0,2)[12] intercept
# Total fit time: 73.292 seconds

# %%
previsao_autoarima = modelo_autoarima.predict(12)
dados_teste["previsao_autoarima"] = previsao_autoarima
plt.figure(figsize=(10,6))
#sns.lineplot(x="Data", y="Casos", data=dados_treino)
sns.lineplot(x="Data", y="Casos", data=dados_teste)
sns.lineplot(x="Data", y="previsao_autoarima", data=dados_teste)
sns.lineplot(x="Data", y="previsao", data=dados_teste)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from sklearn.metrics import mean_squared_error

resultado_autoarima = mean_squared_error(dados_teste["Casos"], dados_teste["previsao_autoarima"])
resultado_arima = mean_squared_error(dados_teste["Casos"], dados_teste["previsao"])
print(f"Autoarima = {resultado_autoarima}")
print(f"Arima = {resultado_arima}")
# Out:
# Autoarima = 113249.88122700033
# Arima = 131384.38760114345

# %%
dados_treino.head()
# Out:
#         Data  Casos  Media_Movel_3  ...  Media_Movel_12_center   Ano  Mês
# 0 2001-01-01   8088            NaN  ...                    NaN  2001    1
# 1 2001-02-01   6542            NaN  ...                    NaN  2001    2
# 2 2001-03-01   8095    7575.000000  ...                    NaN  2001    3
# 3 2001-04-01   7305    7314.000000  ...                    NaN  2001    4
# 4 2001-05-01   7656    7685.333333  ...                    NaN  2001    5
#
# [5 rows x 8 columns]

# %%
from fbprophet import Prophet

modelo_profeta = Prophet(seasonality_mode="multiplicative")
mapa = {"Data": "ds", "Casos": "y"}
dados_treino_profeta = dados_treino[["Data", "Casos"]].rename(mapa,axis=1)
modelo_profeta_treinado = modelo_profeta.fit(dados_treino_profeta)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
futuro = modelo_profeta_treinado.make_future_dataframe(periods=12, freq="M")
futuro
# Out:
#             ds
# 0   2001-01-01
# 1   2001-02-01
# 2   2001-03-01
# 3   2001-04-01
# 4   2001-05-01
# ..         ...
# 223 2019-07-31
# 224 2019-08-31
# 225 2019-09-30
# 226 2019-10-31
# 227 2019-11-30
#
# [228 rows x 1 columns]

# %%
resultado_profeta = modelo_profeta_treinado.predict(futuro)
resultado_profeta
# Out:
#             ds        trend  ...  additive_terms_upper         yhat
# 0   2001-01-01  7677.431620  ...                   0.0  7841.925017
# 1   2001-02-01  7674.773971  ...                   0.0  6907.458238
# 2   2001-03-01  7672.373514  ...                   0.0  8251.985125
# 3   2001-04-01  7669.715865  ...                   0.0  7777.648893
# 4   2001-05-01  7667.143946  ...                   0.0  7760.241704
# ..         ...          ...  ...                   ...          ...
# 223 2019-07-31  7843.214052  ...                   0.0  7986.347122
# 224 2019-08-31  7855.461529  ...                   0.0  7859.591875
# 225 2019-09-30  7867.313926  ...                   0.0  8304.062207
# 226 2019-10-31  7879.561403  ...                   0.0  7659.985529
# 227 2019-11-30  7891.413800  ...                   0.0  7130.969893
#
# [228 rows x 16 columns]

# %%
modelo_profeta_treinado.plot(resultado_profeta);
