# %% [markdown]
# # Modulo 1 - Desafios

# %% [markdown]
# ##Desafio 01: Escolher um título mais descritivo, que passe a mensagem adequada ao gráfico de barras.

# %%
import pandas as pd

# %%
dados = pd.read_csv("/content/A151346189_28_143_208.csv", encoding="ISO-8859-1", 
                    skiprows = 3, sep=";", skipfooter=12,
                    thousands=".", decimal=",")
dados.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
#   Unidade da Federação     2008/Jan  ...     2020/Ago         Total
# 0          11 Rondônia   1388528.39  ...  10285455.78  9.291297e+08
# 1              12 Acre    902416.00  ...            -  4.206680e+08
# 2          13 Amazonas   4735529.42  ...  14726443.67  1.771655e+09
# 3           14 Roraima    657889.53  ...   2826486.18  3.050109e+08
# 4              15 Pará  18864744.11  ...  39911193.02  4.437116e+09
#
# [5 rows x 154 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

ax = dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize=(9,6),grid=True,)
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("Recursos financeiros disponíveis para a Assistência à Saúde da População \n por Unidade da Federação", fontsize= 16)
plt.show()

# %%
dados["2008/Ago"].sum()
# Out:
# 750608648.28

# %%
dados["2020/Ago"].sum()
# Out:
# '10285455.78-14726443.672826486.1839911193.022942273.948240261.3828587541.7823210624.2059808605.5924929930.7222130016.8175704177.7219754741.7811014180.8980793117.08168024412.9532188873.8895274486.35346512263.17129375911.5463972379.36101374341.5119241624.0217790649.8743984702.0526526196.39'

# %% [markdown]
# ##Desafio 02: Faça a mesma análise realizada em aula, porém para o mês mais recente.

# %%
# dados.iloc[:,-2]
dados.replace('-',0, inplace=True)
dados["2020/Ago"] = dados["2020/Ago"].astype('float64')

ax = dados.plot(x="Unidade da Federação", y="2020/Ago", kind="bar", figsize=(9,6),grid=True, color= 'red')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("Recursos financeiros disponíveis para a Assistência à Saúde da População \n por Unidade da Federação", fontsize= 16)
plt.show()

# %%
dados.dtypes
# Out:
# Unidade da Federação     object
# 2008/Jan                float64
# 2008/Fev                float64
# 2008/Mar                float64
# 2008/Abr                float64
#                          ...
# 2020/Mai                float64
# 2020/Jun                float64
# 2020/Jul                float64
# 2020/Ago                float64
# Total                   float64
# Length: 154, dtype: object
